# %% [markdown]
# <a href="https://colab.research.google.com/github/Munazir/Deep-Learning-with-TensorFlow/blob/master/Intro2AIML2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # House price prediction Exercise1

# %%
## import the necesary libraries
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras

# %%
#Build the model with one layer plus one neuron
model = tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
## Compile the model
model.compile(optimizer='sgd',loss='mean_squared_error')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
## Data
xs = np.array([1,2,3,4,5,6],dtype=float)
ys = np.array([100,150,200,250,300,350],dtype=float)

# %%
## Train the Neural Network on this data
model.fit(xs,ys,epochs=500)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 0s 406us/sample - loss: 58.6869
# Epoch 2/500
# 6/6 [==============================] - 0s 757us/sample - loss: 58.2593
# Epoch 3/500
# 6/6 [==============================] - 0s 407us/sample - loss: 57.8349
# Epoch 4/500
# 6/6 [==============================] - 0s 445us/sample - loss: 57.4135
# Epoch 5/500
# 6/6 [==============================] - 0s 632us/sample - loss: 56.9953
# Epoch 6/500
# 6/6 [==============================] - 0s 368us/sample - loss: 56.5800
# Epoch 7/500
# 6/6 [==============================] - 0s 587us/sample - loss: 56.1677
# Epoch 8/500
# 6/6 [==============================] - 0s 391us/sample - loss: 55.7585
# Epoch 9/500
# 6/6 [==============================] - 0s 264us/sample - loss: 55.3523
# Epoch 10/500
# 6/6 [==============================] - 0s 278us/sample - loss: 54.9490
# Epoch 11/500
# 6/6 [==============================] - 0s 362us/sample - loss: 54.5486
# Epoch 12/500
# ...

# %%
model.predict([7.0])
# Out:
# array([[401.7825]], dtype=float32)
